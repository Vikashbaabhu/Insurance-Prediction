# %% [markdown]
# <a href="https://colab.research.google.com/github/Vikashbaabhu/Insurance-Prediction/blob/main/Insurance_Prediction_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Insurance Prediction**

# %%
#Dataset - Insurance 
#Dataset Path - /content/insurance prediction.csv

# %% [markdown]
# # **STEPS :-**

# %%
#1. Take the data and create dataframe
#2. Filtering the Data (Data Cleaning, Dropping)
#3. Data Visualisation
#4. Divide the data into input and output
#5. Train and Test variables
#6. Normalize and scaling the data
#7. Running Regressor
#8. Fit the model 
#9. Predict the Output
#10. Evaluating the Accuracy Score

# %% [markdown]
# # 1. Take the data and create dataframe

# %%
import pandas as pd
df = pd.read_csv('/content/insurance prediction.csv')
df
# Out:
#       age  sex     bmi  children  Employment  vehicles  Years  Interest Rate  \
# 0    19.0  0.0  27.900       0.0         1.0       3.0    2.0           0.00
# 1    18.0  1.0  33.770       1.0         0.0       2.0    3.0           0.00
# 2    28.0  1.0  33.000       3.0         0.0       2.0    2.0           0.00
# 3    33.0  1.0  22.705       0.0         0.0       1.0    5.0           0.45
# 4    32.0  1.0  28.880       0.0         0.0       1.0    2.0           0.20
# ..    ...  ...     ...       ...         ...       ...    ...            ...
# 345  34.0  0.0  29.260       3.0         0.0       2.0    3.0           0.20
# 346  33.0  1.0  35.750       2.0         0.0       2.0    3.0           0.00
# 347  46.0  1.0  33.345       1.0         0.0       0.0    2.0           0.00
# 348   NaN  NaN     NaN       NaN         NaN       NaN    NaN            NaN
# 349   NaN  NaN     NaN       NaN         NaN       NaN    NaN            NaN
#
#          charges
# 0    16884.92400
# ...

# %% [markdown]
# # 2. Filtering the Data (Data Cleaning, Dropping)

# %%
# Deleting the last two rows 
df.drop(df.tail(2).index,inplace=True)
df
# Out:
#       age  sex     bmi  children  Employment  vehicles  Years  Interest Rate  \
# 0    19.0  0.0  27.900       0.0         1.0       3.0    2.0           0.00
# 1    18.0  1.0  33.770       1.0         0.0       2.0    3.0           0.00
# 2    28.0  1.0  33.000       3.0         0.0       2.0    2.0           0.00
# 3    33.0  1.0  22.705       0.0         0.0       1.0    5.0           0.45
# 4    32.0  1.0  28.880       0.0         0.0       1.0    2.0           0.20
# ..    ...  ...     ...       ...         ...       ...    ...            ...
# 343  63.0  1.0  36.765       0.0         0.0       0.0   12.0           0.40
# 344  49.0  0.0  41.470       4.0         0.0       2.0    4.0           0.20
# 345  34.0  0.0  29.260       3.0         0.0       2.0    3.0           0.20
# 346  33.0  1.0  35.750       2.0         0.0       2.0    3.0           0.00
# 347  46.0  1.0  33.345       1.0         0.0       0.0    2.0           0.00
#
#          charges
# 0    16884.92400
# ...

# %%
# Getting Information about the dataframe 

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 348 entries, 0 to 347
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            348 non-null    float64
#  1   sex            348 non-null    float64
#  2   bmi            348 non-null    float64
#  3   children       348 non-null    float64
#  4   Employment     348 non-null    float64
#  5   vehicles       348 non-null    float64
#  6   Years          348 non-null    float64
#  7   Interest Rate  348 non-null    float64
#  8   charges        348 non-null    float64
# dtypes: float64(9)
# memory usage: 27.2 KB

# %%
df.head()
# Out:
#     age  sex     bmi  children  Employment  vehicles  Years  Interest Rate  \
# 0  19.0  0.0  27.900       0.0         1.0       3.0    2.0           0.00
# 1  18.0  1.0  33.770       1.0         0.0       2.0    3.0           0.00
# 2  28.0  1.0  33.000       3.0         0.0       2.0    2.0           0.00
# 3  33.0  1.0  22.705       0.0         0.0       1.0    5.0           0.45
# 4  32.0  1.0  28.880       0.0         0.0       1.0    2.0           0.20
#
#        charges
# 0  16884.92400
# 1   1725.55230
# 2   4449.46200
# 3  21984.47061
# 4   3866.85520

# %%
df.tail()
# Out:
#       age  sex     bmi  children  Employment  vehicles  Years  Interest Rate  \
# 343  63.0  1.0  36.765       0.0         0.0       0.0   12.0            0.4
# 344  49.0  0.0  41.470       4.0         0.0       2.0    4.0            0.2
# 345  34.0  0.0  29.260       3.0         0.0       2.0    3.0            0.2
# 346  33.0  1.0  35.750       2.0         0.0       2.0    3.0            0.0
# 347  46.0  1.0  33.345       1.0         0.0       0.0    2.0            0.0
#
#          charges
# 343  13981.85035
# 344  10977.20630
# 345   6184.29940
# 346   4889.99950
# 347   8334.45755

# %%
df.shape
# Out:
# (348, 9)

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'Employment', 'vehicles', 'Years',
#        'Interest Rate', 'charges'],
#       dtype='object')

# %%
df.describe()
# Out:
#               age         sex         bmi    children  Employment    vehicles  \
# count  348.000000  348.000000  348.000000  348.000000  348.000000  348.000000
# mean    39.591954    0.508621   30.676552    1.091954    0.232759    1.497126
# std     14.417015    0.500646    5.625850    1.192021    0.423198    1.104089
# min     18.000000    0.000000   15.960000    0.000000    0.000000    0.000000
# 25%     27.000000    0.000000   26.782500    0.000000    0.000000    1.000000
# 50%     40.000000    1.000000   30.300000    1.000000    0.000000    2.000000
# 75%     53.000000    1.000000   34.777500    2.000000    0.000000    2.000000
# max     64.000000    1.000000   49.060000    5.000000    1.000000    3.000000
#
#             Years  Interest Rate       charges
# count  348.000000     348.000000    348.000000
# mean     3.977011       0.182960  14016.426293
# std      2.395851       0.215541  12638.887852
# min      1.000000       0.000000   1137.011000
# ...

# %%
df.nunique()
# Out:
# age               47
# sex                2
# bmi              247
# children           6
# Employment         2
# vehicles           4
# Years             14
# Interest Rate     11
# charges          348
# dtype: int64

# %%
df.isnull().sum()
# Out:
# age              0
# sex              0
# bmi              0
# children         0
# Employment       0
# vehicles         0
# Years            0
# Interest Rate    0
# charges          0
# dtype: int64

# %% [markdown]
# # 3. Data Visualisation

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
correlation = df.corr()
sns.heatmap(correlation,xticklabels=correlation.columns,yticklabels=correlation.columns,annot=True)

# %%
sns.pairplot(df)

# %% [markdown]
# #4. Divide the data into input and output

# %%
# Input - age, sex, bmi, children, Employment, vehicles, Years, Interest, Rate
# Output - charges

# %%
# Input
x = df.iloc[:,0:8].values 
x
# Out:
# array([[19.   ,  0.   , 27.9  , ...,  3.   ,  2.   ,  0.   ],
#        [18.   ,  1.   , 33.77 , ...,  2.   ,  3.   ,  0.   ],
#        [28.   ,  1.   , 33.   , ...,  2.   ,  2.   ,  0.   ],
#        ...,
#        [34.   ,  0.   , 29.26 , ...,  2.   ,  3.   ,  0.2  ],
#        [33.   ,  1.   , 35.75 , ...,  2.   ,  3.   ,  0.   ],
#        [46.   ,  1.   , 33.345, ...,  0.   ,  2.   ,  0.   ]])

# %%
# Output 
y = df.iloc[:,8].values
y
# Out:
# array([16884.924  ,  1725.5523 ,  4449.462  , 21984.47061,  3866.8552 ,
#         3756.6216 ,  8240.5896 ,  7281.5056 ,  6406.4107 , 28923.13692,
#         2721.3208 , 27808.7251 ,  1826.843  , 11090.7178 , 39611.7577 ,
#         1837.237  , 10797.3362 ,  2395.17155, 10602.385  , 36837.467  ,
#        13228.84695,  4149.736  ,  1137.011  , 37701.8768 ,  6203.90175,
#        14001.1338 , 14451.83515, 12268.63225,  2775.19215, 38711.     ,
#        35585.576  ,  2198.18985,  4687.797  , 13770.0979 , 51194.55914,
#         1625.43375, 15612.19335,  2302.3    , 39774.2763 , 48173.361  ,
#         3046.062  ,  4949.7587 ,  6272.4772 ,  6313.759  ,  6079.6715 ,
#        20630.28351,  3393.35635,  3556.9223 , 12629.8967 , 38709.176  ,
#         2211.13075,  3579.8287 , 23568.272  , 37742.5757 ,  8059.6791 ,
#        47496.49445, 13607.36875, 34303.1672 , 23244.7902 ,  5989.52365,
#         8606.2174 ,  4504.6624 , 30166.61817,  4133.64165, 14711.7438 ,
# ...

# %% [markdown]
# #5. Train and Test variables

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state = 0)

# %%
#After train_test_split ,

# Training varaibles get 75% data of x and y
# Testing variables get 25% data from x and y

# %%
print(x.shape) 
print(x_train.shape)
print(x_test.shape)
# Out:
# (348, 8)
# (261, 8)
# (87, 8)

# %%
print(y.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (348,)
# (261,)
# (87,)

# %%
# We don't perform step 6 here.

# %% [markdown]
# #7. Run Linear Regression

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %% [markdown]
# #8. Fit the model

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #9. Predict the output

# %%
y_pred = model.predict(x_test) 
y_pred
# Out:
# array([11139.83066619, 35338.57442255,  9585.87988981, 14281.58537036,
#         4776.63431088,  6677.26338485,  5289.5911385 , 18314.30948503,
#         5595.26951213,  5105.87421531, 12679.10640307,  9673.70311909,
#        31887.82780681, 14167.33901884, 39987.83759145,  3405.42362213,
#          624.12597538, 13817.72390661,  1914.36323387, 31907.52460025,
#         5024.36871017, 14691.54061161,   790.57759558, 40449.5900518 ,
#         5106.61583532, 11980.24553703,  1183.07875396, 11016.65188763,
#         5421.43835915, 41578.23183177, 25061.68904608,  9643.09218842,
#         9240.4685486 , 13738.41628062, 40959.37306237,  8697.33809961,
#         9409.81653481,   -77.13406048,  5648.39245093, 15001.94747309,
#         9015.49460594, 11111.67291107, 30459.72665707, 12282.52397723,
#        14720.29914764,  1644.63044896,  3627.43425829, 41492.47728759,
#        17624.17956722,  3477.58027992,  2022.14420203, 11090.33272708,
# ...

# %%
# ACTUAL OUTPUT VALUES
y_test
# Out:
# array([ 8240.5896 , 23568.272  ,  9282.4806 , 20630.28351,  3906.127  ,
#         4922.9159 ,  4883.866  , 11381.3254 ,  2026.9741 ,  4040.55825,
#         9144.565  ,  5920.1041 , 19515.5416 , 11163.568  , 30184.9367 ,
#         1261.442  ,  1632.56445, 13937.6665 ,  2483.736  , 19444.2658 ,
#         1986.9334 , 12928.7911 ,  2302.3    , 30942.1918 ,  5125.2157 ,
#        14451.83515,  1837.237  , 11082.5772 ,  3947.4131 , 48824.45   ,
#        14711.7438 ,  8606.2174 ,  8059.6791 , 11488.31695, 47496.49445,
#         6186.127  ,  8232.6388 ,  1832.094  ,  2755.02095, 13228.84695,
#         9855.1314 ,  8538.28845, 17179.522  , 10564.8845 , 13880.949  ,
#        21344.8467 ,  3645.0894 , 48549.17835, 13405.3903 ,  2404.7338 ,
#         2457.21115,  8334.45755, 24873.3849 ,  7281.5056 ,  1743.214  ,
#         4337.7352 , 19964.7463 , 20277.80751,  7726.854  ,  5989.52365,
#         4260.744  , 13047.33235, 13607.36875, 16297.846  , 20745.9891 ,
# ...

# %%
# Individual Prediction 
model.predict([[34,1,40.5,0,1,2,6,0.5]])
# Out:
# array([34201.35593806])

# %%
model.predict([[85,0,94.74,1,1,4,8,0.35]])
# Out:
# array([65314.32201651])

# %%
model.predict([[67,1,19.89,0,0,0,5,0.16]])
# Out:
# array([11921.69829181])

# %%
model.predict([[13,1,71.97,1,0,3,6,0.49]])
# Out:
# array([13604.36388688])

# %%
model.predict([[58,0,24.63,1,1,5,1,0.9]])
# Out:
# array([37318.06787814])

# %%
# Caculating m (slope)
m = model.coef_
m
# Out:
# array([  275.23115763,   -53.21295479,   302.45002297,   662.6559328 ,
#        25057.29978029,    60.21277219,   -76.43665612,    80.88884167])

# %%
# Calculate C 
C = model.intercept_ 
C
# Out:
# -12112.066205603487

# %% [markdown]
# #10. Evaluating the Accuracy Score

# %%
# Accuracy of the model
from sklearn.metrics import r2_score
r2_score(y_pred,y_test)*100
# Out:
# 70.9302855928847
